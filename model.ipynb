# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
data=pd.read_csv("D:\\Python Projects\\AI-ML\\Hand Gesture Drone Control\\Drone-Control-Ver2\\normalized_training_set_left_hand.csv")
data = data.sample(frac=1, random_state=42).reset_index(drop=True)

y=data.pop("Gesture")
X=data

gesture_unique=["Pitch_Forward","Pitch_Backward","Roll_Left","Roll_Right","Yaw_Left","Yaw_Right","Stop","Thrust_Up","Down"]

for i in range(len(y)):
    y.loc[i]=int(gesture_unique.index(y[i]))

y=y.astype("int64")



X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=69)
# Out:
# C:\Users\Aaryaman Bisht\AppData\Local\Temp\ipykernel_13280\1778572769.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.loc[i]=int(gesture_unique.index(y[i]))
# C:\Users\Aaryaman Bisht\AppData\Local\Temp\ipykernel_13280\1778572769.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y.loc[i]=int(gesture_unique.index(y[i]))
# C:\Users\Aaryaman Bisht\AppData\Local\Temp\ipykernel_13280\1778572769.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
model=tf.keras.Sequential([
    tf.keras.layers.Dense(units=400,activation="relu",input_shape=(X.shape[1],)),
    tf.keras.layers.Dense(units=128,activation="relu"),
    tf.keras.layers.Dense(units=64,activation="relu"),
    tf.keras.layers.Dense(units=9,activation="softmax")
])
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(0.001),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

history=model.fit(X,y,epochs=200,batch_size=1)

result=model.evaluate(X_test,y_test)

print(f"Score is:{result}")
model.save("D:\\Python Projects\\AI-ML\\Hand Gesture Drone Control\\Drone-Control-Ver2\\gesture_recog_model_left_hand.h5")
# Out:
# Epoch 1/200
# c:\Users\Aaryaman Bisht\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.8803 - sparse_categorical_accuracy: 0.3613
# Epoch 2/200
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6402 - sparse_categorical_accuracy: 0.7898
# Epoch 3/200
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3139 - sparse_categorical_accuracy: 0.9314
# Epoch 4/200
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1960 - sparse_categorical_accuracy: 0.9745
# Epoch 5/200
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1688 - sparse_categorical_accuracy: 0.9740
# Epoch 6/200
# ...
